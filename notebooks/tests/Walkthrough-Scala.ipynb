// %%
// modify to IP and Port of this notebook server
%addjar http://127.0.0.1:9500/nbextensions/urth_widgets/urth-widgets.jar

// %%
// modify to IP and Port of this notebook server
%addjar http://127.0.0.0:9500/nbextensions/urth_widgets/urth-widgets.jar

// %%
// modify to IP and Port of this notebook server
%addjar http://localhost:9500/nbextensions/urth_widgets/urth-widgets.jar

// %%
// modify to IP and Port of this notebook server
%addjar http://192.168.99.100:9500/nbextensions/urth_widgets/urth-widgets.jar

// %%
import urth.widgets._
initWidgets
